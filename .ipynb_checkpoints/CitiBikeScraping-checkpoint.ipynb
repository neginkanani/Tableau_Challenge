# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
import urllib.request 
import zipfile

# %%
'''Scrape the citibike website to collect the zipfiles'''
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
#reading the html code
html = browser.html
soup = BeautifulSoup(html, "lxml")

url_citi = 'https://s3.amazonaws.com/tripdata/index.html'
browser.visit(url_citi)
time.sleep(1)


citibike_data = []
for j in range(101):
    citibike = browser.find_by_xpath('//*[@id="tbody-content"]/tr'+ str([j]) +'/td[1]/a[@href]')
    for i in citibike:
        title_link = i.text
        citibike_data.append(title_link)
        time.sleep(2)


browser.quit()
citibike_data
# Out:
# ['201306-citibike-tripdata.zip',
#  '201307-201402-citibike-tripdata.zip',
#  '201307-citibike-tripdata.zip',
#  '201308-citibike-tripdata.zip',
#  '201309-citibike-tripdata.zip',
#  '201310-citibike-tripdata.zip',
#  '201311-citibike-tripdata.zip',
#  '201312-citibike-tripdata.zip',
#  '201401-citibike-tripdata.zip',
#  '201402-citibike-tripdata.zip',
#  '201403-citibike-tripdata.zip',
#  '201404-citibike-tripdata.zip',
#  '201405-citibike-tripdata.zip',
#  '201406-citibike-tripdata.zip',
#  '201407-citibike-tripdata.zip',
#  '201408-citibike-tripdata.zip',
#  '201409-citibike-tripdata.zip',
#  '201410-citibike-tripdata.zip',
#  '201411-citibike-tripdata.zip',
#  '201412-citibike-tripdata.zip',
#  '201501-citibike-tripdata.zip',
#  '201502-citibike-tripdata.zip',
#  '201503-citibike-tripdata.zip',
#  '201504-citibike-tripdata.zip',
#  '201505-citibike-tripdata.zip',
#  '201506-citibike-tripdata.zip',
#  '201507-citibike-tripdata.zip',
#  '201508-citibike-tripdata.zip',
#  '201509-citibike-tripdata.zip',
#  '201510-citibike-tripdata.zip',
#  '201511-citibike-tripdata.zip',
#  '201512-citibike-tripdata.zip',
#  '201601-citibike-tripdata.zip',
#  '201602-citibike-tripdata.zip',
#  '201603-citibike-tripdata.zip',
#  '201604-citibike-tripdata.zip',
#  '201605-citibike-tripdata.zip',
#  '201606-citibike-tripdata.zip',
#  '201607-citibike-tripdata.zip',
#  '201608-citibike-tripdata.zip',
#  '201609-citibike-tripdata.zip',
#  '201610-citibike-tripdata.zip',
#  '201611-citibike-tripdata.zip',
#  '201612-citibike-tripdata.zip',
#  '201701-citibike-tripdata.csv.zip',
#  '201702-citibike-tripdata.csv.zip',
#  '201703-citibike-tripdata.csv.zip',
#  '201704-citibike-tripdata.csv.zip',
#  '201705-citibike-tripdata.csv.zip',
#  '201706-citibike-tripdata.csv.zip',
#  '201707-citibike-tripdata.csv.zip',
#  '201708-citibike-tripdata.csv.zip',
#  '201709-citibike-tripdata.csv.zip',
#  '201710-citibike-tripdata.csv.zip',
#  '201711-citibike-tripdata.csv.zip',
#  '201712-citibike-tripdata.csv.zip',
#  '201801-citibike-tripdata.csv.zip',
#  '201802-citibike-tripdata.csv.zip',
#  '201803-citibike-tripdata.csv.zip',
#  '201804-citibike-tripdata.csv.zip',
#  '201805-citibike-tripdata.csv.zip',
#  '201806-citibike-tripdata.csv.zip',
#  '201807-citibike-tripdata.csv.zip',
#  '201808-citibike-tripdata.csv.zip',
#  '201809-citibike-tripdata.csv.zip',
#  '201810-citibike-tripdata.csv.zip',
#  '201811-citibike-tripdata.csv.zip',
#  '201812-citibike-tripdata.csv.zip',
#  '201901-citibike-tripdata.csv.zip',
#  '201902-citibike-tripdata.csv.zip',
#  '201903-citibike-tripdata.csv.zip',
#  '201904-citibike-tripdata.csv.zip',
#  '201905-citibike-tripdata.csv.zip',
#  '201906-citibike-tripdata.csv.zip',
#  '201907-citibike-tripdata.csv.zip',
#  '201908-citibike-tripdata.csv.zip',
#  '201909-citibike-tripdata.csv.zip',
#  '201910-citibike-tripdata.csv.zip',
#  '201911-citibike-tripdata.csv.zip',
#  '201912-citibike-tripdata.csv.zip',
#  '202001-citibike-tripdata.csv.zip',
#  '202002-citibike-tripdata.csv.zip',
#  '202003-citibike-tripdata.csv.zip',
#  '202004-citibike-tripdata.csv.zip',
#  '202005-citibike-tripdata.csv.zip',
#  '202006-citibike-tripdata.csv.zip',
#  '202007-citibike-tripdata.csv.zip',
#  '202008-citibike-tripdata.csv.zip',
#  '202009-citibike-tripdata.csv.zip',
#  '202010-citibike-tripdata.csv.zip',
#  '202011-citibike-tripdata.csv.zip',
#  '202012-citibike-tripdata.csv.zip',
#  '202101-citibike-tripdata.csv.zip',
#  '202102-citibike-tripdata.csv.zip',
#  '202103-citibike-tripdata.csv.zip',
#  '202104-citibike-tripdata.csv.zip',
#  '202105-citibike-tripdata.csv.zip',
#  '202106-citibike-tripdata.csv.zip',
#  '202107-citibike-tripdata.csv.zip',
#  '202108-citibike-tripdata.csv.zip']

# %%
#Downloading the zipfiles in the same directory as the code here
for j in range(100):
    url = "https://s3.amazonaws.com/tripdata/" + citibike_data [j]
    filename = citibike_data [j]
    urllib.request.urlretrieve(url, filename) 
 
print("Download complete.")
# Out:
# Download complete.

# %%
# read the zip file first we need to get the name of the file without.zip or .zip.csv for the next step
file_name=[]
for j in citibike_data:
    file_name.append(j.split(".")[0])
file_name
# Out:
# ['201306-citibike-tripdata',
#  '201307-201402-citibike-tripdata',
#  '201307-citibike-tripdata',
#  '201308-citibike-tripdata',
#  '201309-citibike-tripdata',
#  '201310-citibike-tripdata',
#  '201311-citibike-tripdata',
#  '201312-citibike-tripdata',
#  '201401-citibike-tripdata',
#  '201402-citibike-tripdata',
#  '201403-citibike-tripdata',
#  '201404-citibike-tripdata',
#  '201405-citibike-tripdata',
#  '201406-citibike-tripdata',
#  '201407-citibike-tripdata',
#  '201408-citibike-tripdata',
#  '201409-citibike-tripdata',
#  '201410-citibike-tripdata',
#  '201411-citibike-tripdata',
#  '201412-citibike-tripdata',
#  '201501-citibike-tripdata',
#  '201502-citibike-tripdata',
#  '201503-citibike-tripdata',
#  '201504-citibike-tripdata',
#  '201505-citibike-tripdata',
#  '201506-citibike-tripdata',
#  '201507-citibike-tripdata',
#  '201508-citibike-tripdata',
#  '201509-citibike-tripdata',
#  '201510-citibike-tripdata',
#  '201511-citibike-tripdata',
#  '201512-citibike-tripdata',
#  '201601-citibike-tripdata',
#  '201602-citibike-tripdata',
#  '201603-citibike-tripdata',
#  '201604-citibike-tripdata',
#  '201605-citibike-tripdata',
#  '201606-citibike-tripdata',
#  '201607-citibike-tripdata',
#  '201608-citibike-tripdata',
#  '201609-citibike-tripdata',
#  '201610-citibike-tripdata',
#  '201611-citibike-tripdata',
#  '201612-citibike-tripdata',
#  '201701-citibike-tripdata',
#  '201702-citibike-tripdata',
#  '201703-citibike-tripdata',
#  '201704-citibike-tripdata',
#  '201705-citibike-tripdata',
#  '201706-citibike-tripdata',
#  '201707-citibike-tripdata',
#  '201708-citibike-tripdata',
#  '201709-citibike-tripdata',
#  '201710-citibike-tripdata',
#  '201711-citibike-tripdata',
#  '201712-citibike-tripdata',
#  '201801-citibike-tripdata',
#  '201802-citibike-tripdata',
#  '201803-citibike-tripdata',
#  '201804-citibike-tripdata',
#  '201805-citibike-tripdata',
#  '201806-citibike-tripdata',
#  '201807-citibike-tripdata',
#  '201808-citibike-tripdata',
#  '201809-citibike-tripdata',
#  '201810-citibike-tripdata',
#  '201811-citibike-tripdata',
#  '201812-citibike-tripdata',
#  '201901-citibike-tripdata',
#  '201902-citibike-tripdata',
#  '201903-citibike-tripdata',
#  '201904-citibike-tripdata',
#  '201905-citibike-tripdata',
#  '201906-citibike-tripdata',
#  '201907-citibike-tripdata',
#  '201908-citibike-tripdata',
#  '201909-citibike-tripdata',
#  '201910-citibike-tripdata',
#  '201911-citibike-tripdata',
#  '201912-citibike-tripdata',
#  '202001-citibike-tripdata',
#  '202002-citibike-tripdata',
#  '202003-citibike-tripdata',
#  '202004-citibike-tripdata',
#  '202005-citibike-tripdata',
#  '202006-citibike-tripdata',
#  '202007-citibike-tripdata',
#  '202008-citibike-tripdata',
#  '202009-citibike-tripdata',
#  '202010-citibike-tripdata',
#  '202011-citibike-tripdata',
#  '202012-citibike-tripdata',
#  '202101-citibike-tripdata',
#  '202102-citibike-tripdata',
#  '202103-citibike-tripdata',
#  '202104-citibike-tripdata',
#  '202105-citibike-tripdata',
#  '202106-citibike-tripdata',
#  '202107-citibike-tripdata',
#  '202108-citibike-tripdata']

# %%
#Now read the csv inside zipfile and include very 1000 rows
df_all=pd.DataFrame()
for j in citibike_data:
    zf = zipfile.ZipFile('C:/Users/nkananizadeh/Desktop/Negin/Tableau/'+j) 
    try:
        df = pd.read_csv(zf.open(str(j.split(".")[0])+".csv"))[::1000]
        df_all= pd.concat([df_all,df])
    except:
        print("not a good data:" +str(j.split(".")[0]))
# Out:
# not a good data:201307-201402-citibike-tripdata
# not a good data:201307-citibike-tripdata
# not a good data:201308-citibike-tripdata
# not a good data:201309-citibike-tripdata
# not a good data:201310-citibike-tripdata
# not a good data:201311-citibike-tripdata
# not a good data:201312-citibike-tripdata
# not a good data:201401-citibike-tripdata
# not a good data:201402-citibike-tripdata
# not a good data:201403-citibike-tripdata
# not a good data:201404-citibike-tripdata
# not a good data:201405-citibike-tripdata
# not a good data:201406-citibike-tripdata
# not a good data:201407-citibike-tripdata
# not a good data:201408-citibike-tripdata
# C:\Users\nkananizadeh\AppData\Local\Temp\ipykernel_25968\4187934349.py:6: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(str(j.split(".")[0])+".csv"))[::1000]
# C:\Users\nkananizadeh\AppData\Local\Temp\ipykernel_25968\4187934349.py:6: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(str(j.split(".")[0])+".csv"))[::1000]
# C:\Users\nkananizadeh\AppData\Local\Temp\ipykernel_25968\4187934349.py:6: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(str(j.split(".")[0])+".csv"))[::1000]
# C:\Users\nkananizadeh\AppData\Local\Temp\ipykernel_25968\4187934349.py:6: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(str(j.split(".")[0])+".csv"))[::1000]
# C:\Users\nkananizadeh\AppData\Local\Temp\ipykernel_25968\4187934349.py:6: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(str(j.split(".")[0])+".csv"))[::1000]
# C:\Users\nkananizadeh\AppData\Local\Temp\ipykernel_25968\4187934349.py:6: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(str(j.split(".")[0])+".csv"))[::1000]
# C:\Users\nkananizadeh\AppData\Local\Temp\ipykernel_25968\4187934349.py:6: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(str(j.split(".")[0])+".csv"))[::1000]

# %%
df_all
# Out:
#          tripduration            starttime             stoptime  \
# 0               695.0  2013-06-01 00:00:01  2013-06-01 00:11:36
# 1000           1854.0  2013-06-01 10:03:33  2013-06-01 10:34:27
# 2000           4310.0  2013-06-01 12:20:04  2013-06-01 13:31:54
# 3000            844.0  2013-06-01 13:55:28  2013-06-01 14:09:32
# 4000            215.0  2013-06-01 15:21:42  2013-06-01 15:25:17
# ...               ...                  ...                  ...
# 3068000           NaN                  NaN                  NaN
# 3069000           NaN                  NaN                  NaN
# 3070000           NaN                  NaN                  NaN
# 3071000           NaN                  NaN                  NaN
# 3072000           NaN                  NaN                  NaN
#
#          start station id     start station name  start station latitude  \
# 0                   444.0     Broadway & W 24 St               40.742354
# 1000                217.0          Old Fulton St               40.702772
# 2000                304.0  Broadway & Battery Pl               40.704633
# 3000                479.0        9 Ave & W 45 St               40.760193
# 4000                294.0    Washington Square E               40.730494
# ...                   ...                    ...                     ...
# 3068000               NaN                    NaN                     NaN
# 3069000               NaN                    NaN                     NaN
# 3070000               NaN                    NaN                     NaN
# 3071000               NaN                    NaN                     NaN
# 3072000               NaN                    NaN                     NaN
#
#          start station longitude  end station id  end station name  \
# 0                     -73.989151           434.0   9 Ave & W 18 St
# 1000                  -73.993836           461.0   E 20 St & 2 Ave
# 2000                  -74.013617           530.0  11 Ave & W 59 St
# 3000                  -73.991255           442.0   W 27 St & 7 Ave
# 4000                  -73.995721           403.0    E 2 St & 2 Ave
# ...                          ...             ...               ...
# 3068000                      NaN             NaN               NaN
# 3069000                      NaN             NaN               NaN
# 3070000                      NaN             NaN               NaN
# 3071000                      NaN             NaN               NaN
# 3072000                      NaN             NaN               NaN
#
#          end station latitude  ...             ended_at  \
# 0                   40.743174  ...                  NaN
# 1000                40.735877  ...                  NaN
# 2000                40.771522  ...                  NaN
# 3000                40.746647  ...                  NaN
# 4000                40.725029  ...                  NaN
# ...                       ...  ...                  ...
# 3068000                   NaN  ...  2021-08-12 10:23:18
# 3069000                   NaN  ...  2021-09-01 02:30:36
# 3070000                   NaN  ...  2021-08-07 11:59:30
# 3071000                   NaN  ...  2021-08-24 16:33:35
# 3072000                   NaN  ...  2021-08-24 19:12:33
#
#                  start_station_name start_station_id  \
# 0                               NaN              NaN
# 1000                            NaN              NaN
# 2000                            NaN              NaN
# 3000                            NaN              NaN
# 4000                            NaN              NaN
# ...                             ...              ...
# 3068000             E 74 St & 1 Ave          6953.08
# 3069000       Bailey Ave & W 193 St          8676.01
# 3070000  Underhill Ave & Pacific St          4231.04
# 3071000      West End Ave & W 94 St          7524.09
# 3072000    Montague St & Clinton St          4677.06
#
#                   end_station_name  end_station_id  start_lat  start_lng  \
# 0                              NaN             NaN        NaN        NaN
# 1000                           NaN             NaN        NaN        NaN
# 2000                           NaN             NaN        NaN        NaN
# 3000                           NaN             NaN        NaN        NaN
# 4000                           NaN             NaN        NaN        NaN
# ...                            ...             ...        ...        ...
# 3068000            E 85 St & 3 Ave         7212.05  40.768974 -73.954823
# 3069000  W 192 St & University Ave         8639.01  40.870690 -73.906780
# 3070000            7 Ave & Park Pl         4125.07  40.680484 -73.964680
# 3071000     W 84 St & Columbus Ave         7382.04  40.794165 -73.974124
# 3072000       Union St & Nevins St         4143.03  40.694271 -73.992327
#
#            end_lat    end_lng member_casual
# 0              NaN        NaN           NaN
# 1000           NaN        NaN           NaN
# 2000           NaN        NaN           NaN
# 3000           NaN        NaN           NaN
# 4000           NaN        NaN           NaN
# ...            ...        ...           ...
# 3068000  40.778012 -73.954071        casual
# 3069000  40.866899 -73.901942        casual
# 3070000  40.677615 -73.973243        member
# 3071000  40.785000 -73.972834        member
# 3072000  40.679098 -73.987655        member
#
# [118487 rows x 43 columns]

# %%
df_all.to_csv('combined.csv', index=False)
